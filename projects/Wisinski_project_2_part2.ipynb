# %% [markdown]
# <img src="https://images.efollett.com/htmlroot/images/templates/storeLogos/CA/864.gif" style="float: right;">
#
#
#
#
# # ECON628-01
# ### Wisinski_Project_02-  With Guidelines

# %% [markdown]
# ---
# ### The project
# ---
# This is a project to show your understanding and skills to:
#
# - Extract (unstructured) secondary datasets from sources such as:
#     - [Public Datasets][1]
#     - [Data World][2]
#     - And More
# [1]: https://github.com/caesar0301/awesome-public-datasets "Public Datasets"
# [2]: https://data.world/ "Data World"
#
# - Combine multiple datasets that are relevant to your hypothesis.
# - Clearly defined problem statement/goal/hypothesis.
# - Perform an EDA relevant to your problem statement.
# - Implement Machine Learning models to answer you hypothesis.
# - Explanation of all metrics and charts.
# - Provide a technical and non technical conclusion from your findings.
# - Treat this project as your first case study assignment at the place where you envision yourself working after graduation
#     - The best way to pick a topic => search for openings/projects at the organizations where you want to work (i.e. IPA)
#     - See if you can get a dataset that they are using/have used in previous projects and try to replicate their work
#     - Or you can get a dataset from other country and see if you can replicate their approach (i.e. [Violence in Medellin Colombia][3])
# [3]: http://www.poverty-action.org/job/research-analyst-crime-violence-reduction "Violence in Medellin Colombia"
#
#
# ---
# ### The Macro Picture Guidelines
# ---
# - Clearly defined problem statement/goal/hypothesis.
# - EDA relevant to your problem statement.
#     - Describe your data, including the source(s).
#     - Describe relevant data cleaning and munging.
# - Record any quality assessment and assumptions that you are making based on the EDA.
# - Well-documented code of the modeling you performed to answer your question.
# - Clear description of model selection.
#     * This should address why you have selected the model or models to answer your question and why the choice is appropriate.
# - Description of results.
#     * Includes relevant code, metrics, and visualizations that describe your results.
# - Explanation Technically and non-technically of all metrics and charts.
# - Conclusion/Summarize your findings, addressing the strengths and weaknesses of your approach.
# - Recommendations and future directions.
#
# ---
# ### What you need to push/turn in and deadlines
# ---
#
# &nbsp;
#
# - **Monday April 3** => Links to your datasets, use this [form][4] to submit your links
#     - No emails, slack messages => you need to use the form
# [4]: https://docs.google.com/forms/d/e/1FAIpQLSewogWOmrRcC6zGWnm0gZA6DAjoWVLTvcAXfbKJR0x-QLm54g/viewform "form"
#
# &nbsp;
#
# - **April 10** => EDA notebooks, use this [form][5] to submit your links
#     - No emails, slack messages => you need to use the form
# [5]: https://docs.google.com/forms/d/e/1FAIpQLScLa5EL89EWeqHxE73WHznADOcQyCWt8w0Ms2YqB4iiMwtyiA/viewform "form"
#
#
# &nbsp;
#
# - **April 17** => EDA notebooks and Modeling notebooks, use this [form][6] to submit your links
#     - No emails, slack messages => you need to use the form
# [6]: https://docs.google.com/forms/d/e/1FAIpQLScbe0McdgVCcWjbkqyPJzh4vWGSB0Hd7jZaWVKusLg0KAfFLg/viewform "form"
#
#
# &nbsp;
#
#
# - **April 24** => **Final documents** are due on **April 24** (the date could change)
#     - No emails, slack messages => you need to use the form
#     - **Final documents** = EDA notebooks with code only
#     - **Final documents** = Models notebooks with code only
#     - **Final documents** = One short technical and One short non-techincal (blog post type) reports of your findings

# %%
# data modules
import numpy as np
import scipy.stats as stats
import pandas as pd

# plotting modules
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# Stats/Regresions Packages
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# make sure charts appear in the notebook:
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
path_to_file = '/Users/Theodore/Desktop/ECON628-01twisinski5026/datasets/project2/cepiipartnerid.csv'
cepipid = pd.read_csv(path_to_file)
# Out:
# C:\Users\Theodore\Anaconda2\envs\econ\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
path_to_file = '/Users/Theodore/Desktop/ECON628-01twisinski5026/datasets/project2/importsexportspartnerid.csv'
tradepid = pd.read_csv(path_to_file)

# %%
path_to_file = '/Users/Theodore/Desktop/ECON628-01twisinski5026/datasets/project2/theilliso.csv'
thiso = pd.read_csv(path_to_file)

# %%
path_to_file = '/Users/Theodore/Desktop/ECON628-01twisinski5026/datasets/project2/schol_o.csv'
schoolo = pd.read_csv(path_to_file)

# %%
path_to_file = '/Users/Theodore/Desktop/ECON628-01twisinski5026/datasets/project2/schol_d.csv'
schoold = pd.read_csv(path_to_file)

# %% [raw]
# Data Dictionary of CEPII data
#
# iso3_o	      ISO3 alphanumeric 3 letter country code origin of trade
# iso3_d	      ISO3 alphanumeric 3 letter country code destination of trade
# year	      Year
# contig	      1 for contiguity
# comlang_off	  1 for common official of primary language
# comlang_ethno 1 if a language is spoken by at least 9% of the population in both countries
# comcol	      1 for common colonizer post 1945
# col45	      1 for pairs in colonial relationship post 1945
# distw	      weighted distance (pop-wt, km)
# pop_o	      Population, total in mn
# gdp_o	      GDP (current mn US$)
# gdpcap_o	  GDP per cap (current in US$)
# iso2_o	      ISO2 alphanumeric
# area_o	      Area in sq. kms
# pop_d	      Population, total in mn
# gdp_d	      GDP (current mn US$)
# gdpcap_d	  GDP per cap (current in US$)
# iso2_d	      ISO2 alphanumeric
# area_d	      Area in sq. kms
# tdiff	      nb of hours difference between ex and im
# heg_d	      destination is current or former hegemon of origin
# conflict	  1 if war
# indepdate	  Independence date if colony == 1
# heg_o	      origin is current or former hegemon of destination
# col_to	      1 for trade from heg_o to colony
# col_fr	      1 for trade from colony to heg_d
# colony	      1 for pair ever in colonial relationship
# curcol	      1 for pair currently in colonial relationship
# empire	      empire to which both countries belong to
# gatt_o	      1 if origin is GATT/WTO member
# gatt_d	      1 if destination is GATT/WTO member
# rta	          1 for regional trade agreement in force
# leg_o	      legal origin of exporter
# leg_d	      legal origin of importer
# comleg	      common legal origin
# comcur	      Common Currency
# acp_to_eu	  1 for ACP to EU
# eu_to_acp	  1 for EU to ACP
# Country	      Country
# TH	          Theill wage index of pay to skilled vs unskilled workers in manufacturing sector

# %% [raw]
# Data Dictionary for trade data
#
# exports2d  value of exports in thousands to destination country
# imports2o  value of imports to origin country
# impexp     total value of trade
# partnerid  unique identifier for bilateral trade data

# %% [raw]
# Data Dictionary for schooling data
#
# SCH' '  Average level of educational attainment for destination or origin country at " " year (5 year intervals availability)

# %%
cepipid.describe().T
# Out:
#                    count           mean           std          min  \
# year           2257920.0    1984.000000  1.298718e+01  1962.000000
# contig         2257920.0       0.012277  1.101184e-01     0.000000
# comlang_off    2257920.0       0.174386  3.794413e-01     0.000000
# comlang_ethno  2257920.0       0.169165  3.748973e-01     0.000000
# comcol         2257920.0       0.117307  3.217859e-01     0.000000
# col45          2257920.0       0.006218  7.860948e-02     0.000000
# distw          2257920.0    8484.354990  4.694321e+03     0.995137
# pop_o          1949024.0      24.722602  9.727082e+01     0.016000
# gdp_o          1672608.0  102764.408409  5.512459e+05    12.541635
# gdpcap_o       1665216.0    4101.438239  7.557484e+03     6.813283
# area_o         2257920.0  608248.419643  1.794622e+06     7.000000
# pop_d          1949024.0      24.722602  9.727082e+01     0.016000
# gdp_d          1672608.0  102764.408409  5.512459e+05    12.541635
# ...

# %%
tradepid.describe().T
# Out:
#               count           mean           std     min     25%     50%  \
# year       461370.0    1981.000000  1.125464e+01  1962.0  1971.0  1981.0
# exports2d  227902.0   98501.596625  8.350381e+05     1.0     NaN     NaN
# imports2o  227902.0   98501.596625  8.350381e+05     1.0     NaN     NaN
# impexp     189266.0  235454.832194  1.777620e+06     2.0     NaN     NaN
# partnerid  461370.0    5915.500000  3.415031e+03     1.0  2958.0  5915.5
#
#               75%         max
# year       1991.0      2000.0
# exports2d     NaN  55098362.0
# imports2o     NaN  55098362.0
# impexp        NaN  96604128.0
# partnerid  8873.0     11830.0

# %%
#Cepii dataset is much larger than the trade dataset and much of the Cepii observations will become 
#extraneous once merged with the trade data

cepipid.isnull().sum()
# Out:
# Country1               0
# Country2               0
# iso3_o                 0
# iso3_d                 0
# year                   0
# contig                 0
# comlang_off            0
# comlang_ethno          0
# comcol                 0
# col45                  0
# distw                  0
# pop_o             308896
# gdp_o             585312
# gdpcap_o          592704
# iso2_o             10080
# area_o                 0
# pop_d             308896
# gdp_d             585312
# gdpcap_d          592704
# iso2_d             10080
# area_d                 0
# tdiff                  0
# heg_d                  0
# conflict         2238120
# indepdate        2238120
# heg_o                  0
# col_to                 0
# col_fr                 0
# colony                 0
# curcol                 0
# empire           1821330
# gatt_o                 0
# gatt_d                 0
# rta                10080
# leg_o             211680
# leg_d             211680
# comleg             19845
# ...

# %%
tradepid.isnull().sum()
# Out:
# iso3_o            0
# iso3_d            0
# year              0
# exports2d    233468
# imports2o    233468
# impexp       272104
# partnerid         0
# dtype: int64

# %%
tradepid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461370 entries, 0 to 461369
# Data columns (total 7 columns):
# iso3_o       461370 non-null object
# iso3_d       461370 non-null object
# year         461370 non-null int16
# exports2d    227902 non-null float64
# imports2o    227902 non-null float64
# impexp       189266 non-null float32
# partnerid    461370 non-null float32
# dtypes: float32(2), float64(2), int16(1), object(2)
# memory usage: 22.0+ MB

# %%
cepipid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2257920 entries, 0 to 2257919
# Data columns (total 41 columns):
# Country1         category
# Country2         category
# iso3_o           object
# iso3_d           object
# year             int16
# contig           int8
# comlang_off      int8
# comlang_ethno    int8
# comcol           int8
# col45            int8
# distw            float64
# pop_o            float32
# gdp_o            float32
# gdpcap_o         float32
# iso2_o           object
# area_o           int32
# pop_d            float32
# gdp_d            float32
# gdpcap_d         float32
# iso2_d           object
# area_d           int32
# tdiff            float32
# heg_d            int8
# conflict         float64
# indepdate        float64
# heg_o            int8
# col_to           int8
# col_fr           int8
# colony           int8
# curcol           int8
# empire           object
# gatt_o           int8
# gatt_d           int8
# rta              float64
# ...

# %%
# Citing Stack Overflow: CSV VIA SQL

# As a database guy, I always recommend handling large data loads and merging/joining with a SQL relational engine 
# that scales well for such processes. I have written many a comment on dataframe merge Q/As to this effect
# -even in R. You can use any SQL database including file server dbs (Access, SQLite) or client server dbs 
# (MySQL, MSSQL, or other), even where your dfs derive. Python maintains a built-in library for
# SQLite (otherwise you use ODBC); and dataframes can be pushed into databases as tables using pandas to_sql:

#For these reasons I believe I may be running into this memory error when trying to merge these datasets.  Because
#of this factor, I will be merging these datasets in SQL or in STATA to avoid this issue, despite knowing how to 
#do it in Python.

tradecepii = cepipid.merge(tradepid, on=['partnerid'], how='outer')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-31-0d369d0acc50> in <module>()
#      11 #do it in Python.
#      12
# ---> 13 tradecepii = cepipid.merge(tradepid, on=['partnerid'], how='outer')
#
# C:\Users\Theodore\Anaconda2\envs\econ\lib\site-packages\pandas\core\frame.pyc in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4435                      right_on=right_on, left_index=left_index,
#    4436                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4437                      copy=copy, indicator=indicator)
#    4438
#    4439     def round(self, decimals=0, *args, **kwargs):
#
# C:\Users\Theodore\Anaconda2\envs\econ\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
# ...

# %%
    path_to_file = '/Users/Theodore/Desktop/ECON628-01twisinski5026/datasets/project2/mergedgood.dta'
merged = pd.read_stata(path_to_file)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405840 entries, 0 to 405839
# Data columns (total 45 columns):
# iso3_o           405840 non-null object
# iso3_d           405840 non-null object
# year             405840 non-null int16
# Country1         405840 non-null category
# Country2         405840 non-null category
# contig           405840 non-null int8
# comlang_off      405840 non-null int8
# comlang_ethno    405840 non-null int8
# comcol           405840 non-null int8
# col45            405840 non-null int8
# distw            405840 non-null float64
# pop_o            405840 non-null float32
# gdp_o            381456 non-null float32
# gdpcap_o         381456 non-null float32
# iso2_o           405840 non-null object
# area_o           405840 non-null int32
# pop_d            401166 non-null float32
# gdp_d            371338 non-null float32
# gdpcap_d         371338 non-null float32
# iso2_d           405840 non-null object
# area_d           405840 non-null int32
# ...

# %%
merged.isnull().sum()
# Out:
# iso3_o                0
# iso3_d                0
# year                  0
# Country1              0
# Country2              0
# contig                0
# comlang_off           0
# comlang_ethno         0
# comcol                0
# col45                 0
# distw                 0
# pop_o                 0
# gdp_o             24384
# gdpcap_o          24384
# iso2_o                0
# area_o                0
# pop_d              4674
# gdp_d             34502
# gdpcap_d          34502
# iso2_d                0
# area_d                0
# tdiff                 0
# heg_d                 0
# conflict         402306
# indepdate        402306
# heg_o                 0
# col_to                0
# col_fr                0
# colony                0
# curcol                0
# empire                0
# gatt_o                0
# gatt_d                0
# rta                 988
# leg_o                 0
# leg_d                 0
# comleg                0
# comcur                0
# ...

# %%
#Dropping unneccesary variables

merged.drop(['conflict', 'indepdate', 
          ], axis=1, inplace=True)

# %%
merged.isnull().sum()
# Out:
# iso3_o                0
# iso3_d                0
# year                  0
# Country1              0
# Country2              0
# contig                0
# comlang_off           0
# comlang_ethno         0
# comcol                0
# col45                 0
# distw                 0
# pop_o                 0
# gdp_o             24384
# gdpcap_o          24384
# iso2_o                0
# area_o                0
# pop_d              4674
# gdp_d             34502
# gdpcap_d          34502
# iso2_d                0
# area_d                0
# tdiff                 0
# heg_d                 0
# heg_o                 0
# col_to                0
# col_fr                0
# colony                0
# curcol                0
# empire                0
# gatt_o                0
# gatt_d                0
# rta                 988
# leg_o                 0
# leg_d                 0
# comleg                0
# comcur                0
# acp_to_eu             0
# eu_to_acp             0
# ...

# %%
merged2 = merged.dropna()

# %%
#Still have over 125K entries after dropping missing values.  As there is no best practice to fill the missing values with 
#any type of average, this process should prove adequate for predictive analysis techniques.

merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126042 entries, 11 to 405814
# Data columns (total 43 columns):
# iso3_o           126042 non-null object
# iso3_d           126042 non-null object
# year             126042 non-null int16
# Country1         126042 non-null category
# Country2         126042 non-null category
# contig           126042 non-null int8
# comlang_off      126042 non-null int8
# comlang_ethno    126042 non-null int8
# comcol           126042 non-null int8
# col45            126042 non-null int8
# distw            126042 non-null float64
# pop_o            126042 non-null float32
# gdp_o            126042 non-null float32
# gdpcap_o         126042 non-null float32
# iso2_o           126042 non-null object
# area_o           126042 non-null int32
# pop_d            126042 non-null float32
# gdp_d            126042 non-null float32
# gdpcap_d         126042 non-null float32
# iso2_d           126042 non-null object
# area_d           126042 non-null int32
# ...

# %%
cols = list(merged2.columns.values)

cols
# Out:
# ['iso3_o',
#  'iso3_d',
#  'year',
#  'Country1',
#  'Country2',
#  'contig',
#  'comlang_off',
#  'comlang_ethno',
#  'comcol',
#  'col45',
#  'distw',
#  'pop_o',
#  'gdp_o',
#  'gdpcap_o',
#  'iso2_o',
#  'area_o',
#  'pop_d',
#  'gdp_d',
#  'gdpcap_d',
#  'iso2_d',
#  'area_d',
#  'tdiff',
#  'heg_d',
#  'heg_o',
#  'col_to',
#  'col_fr',
#  'colony',
#  'curcol',
#  'empire',
#  'gatt_o',
#  'gatt_d',
#  'rta',
#  'leg_o',
#  'leg_d',
#  'comleg',
#  'comcur',
#  'acp_to_eu',
#  'eu_to_acp',
#  'TH',
#  'exports2d',
#  'imports2o',
#  'impexp',
#  'partnerid']

# %%
core_var=merged2[['exports2d',
 'imports2o',
 'impexp',
 'contig',
 'comlang_off',
 'comlang_ethno',
 'comcol',
 'col45',
 'distw',
 'pop_o',
 'gdp_o',
 'gdpcap_o',
 'iso2_o',
 'area_o',
 'pop_d',
 'gdp_d',
 'gdpcap_d',
 'iso2_d',
 'area_d',
 'tdiff']]

fig = plt.figure(figsize=(25,15))
ax = fig.gca()
sns.heatmap(core_var.corr(), annot=True, linewidths=.15, cmap="YlGnBu", vmin=0, vmax=1, ax=ax)
plt.show()

# %%
target = 'impexp'
y = merged2[target]
print type(y)

X = merged2[['contig',
 'comlang_off',
 'comlang_ethno',
 'comcol',
 'col45',
 'distw',
 'pop_o',
 'gdp_o',
 'gdpcap_o',
 'area_o',
 'pop_d',
 'gdp_d',
 'gdpcap_d',
 'area_d']]
print type(X)

print y.shape, X.shape
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# (126042L,) (126042, 14)

# %%
from sklearn.preprocessing import StandardScaler

ss=StandardScaler()

Xn = ss.fit_transform(X)

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape
# Out:
# (88229, 14) (88229L,)
# (37813, 14) (37813L,)

# %%
from sklearn import linear_model as lm
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV

# %%
#Using normalized values of x covariates for the train and test data
X_train, X_test, y_train, y_test = train_test_split(Xn, y, test_size=0.30, random_state=10)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape
# Out:
# (88229L, 14L) (88229L,)
# (37813L, 14L) (37813L,)

# %%
#Using Ridge Regression as first regularized prediction method.
ridge_alphas = np.logspace(0, 5, 100)
optimal_ridge = RidgeCV(alphas=ridge_alphas, cv=10)
optimal_ridge.fit(X_train, y_train)
print (optimal_ridge.alpha_)
# Out:
# 2154.43469003

# %%
ridge = Ridge(alpha=optimal_ridge.alpha_)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=2154.4346900318847, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
def rsquare_meansquare_error(train_y, test_y, train_X, test_X, test, best_model):
    y_train_pred = best_model.predict(train_X)
    y_test_pred = best_model.predict(test_X)
    
    print ('MSE ' + test + ' train data: %.2f, test data: %.2f' % (
        mean_squared_error(train_y, y_train_pred),
        mean_squared_error(test_y, y_test_pred)))
    print('R^2 ' + test + ' train data: %.2f, test data: %.2f' % (
        r2_score(train_y, y_train_pred),
        r2_score(test_y, y_test_pred)))

# %%
rsquare_meansquare_error(y_train, y_test, X_train, X_test, "Ridge", ridge)
# Out:
# MSE Ridge train data: 2489955778931.71, test data: 2931382742250.64
# R^2 Ridge train data: 0.16, test data: 0.16
